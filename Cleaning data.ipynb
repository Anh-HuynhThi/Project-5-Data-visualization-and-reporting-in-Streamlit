# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st

# %%
df = pd.read_csv(r'C:\Users\James\Downloads\beer_reviews.csv')
df
# Out:
#            index  brewery_id                 brewery_name  review_time  \
# 0              0       10325              Vecchio Birraio   1234817823
# 1              1       10325              Vecchio Birraio   1235915097
# 2              2       10325              Vecchio Birraio   1235916604
# 3              3       10325              Vecchio Birraio   1234725145
# 4              4        1075      Caldera Brewing Company   1293735206
# ...          ...         ...                          ...          ...
# 1586609  1586609       14359  The Defiant Brewing Company   1162684892
# 1586610  1586610       14359  The Defiant Brewing Company   1161048566
# 1586611  1586611       14359  The Defiant Brewing Company   1160702513
# 1586612  1586612       14359  The Defiant Brewing Company   1160023044
# 1586613  1586613       14359  The Defiant Brewing Company   1160005319
#
#          review_overall  review_aroma  review_appearance review_profilename  \
# ...

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# beer_abv              67785
# review_profilename      348
# brewery_name             15
# index                     0
# brewery_id                0
# review_time               0
# review_overall            0
# review_aroma              0
# review_appearance         0
# beer_style                0
# review_palate             0
# review_taste              0
# beer_name                 0
# beer_beerid               0
# dtype: int64

# %%
df[df['beer_abv'].isna()]
# Out:
#            index  brewery_id                 brewery_name  review_time  \
# 273          273        1075      Caldera Brewing Company   1103668195
# 430          430         850   Moon River Brewing Company   1110736110
# 603          603         850   Moon River Brewing Company   1100038819
# 733          733        1075      Caldera Brewing Company   1260673921
# 798          798        1075      Caldera Brewing Company   1212201268
# ...          ...         ...                          ...          ...
# 1586568  1586568       14359  The Defiant Brewing Company   1187052567
# 1586587  1586587       14359  The Defiant Brewing Company   1177842168
# 1586596  1586596       14359  The Defiant Brewing Company   1287951067
# 1586597  1586597       14359  The Defiant Brewing Company   1241906223
# 1586598  1586598       14359  The Defiant Brewing Company   1236550020
#
#          review_overall  review_aroma  review_appearance review_profilename  \
# ...

# %%
df['beer_abv']=df['beer_abv'].replace(np.nan,df['beer_abv'].mean())

# %%
df[df['review_profilename'].isna()]
# Out:
#            index  brewery_id                                brewery_name  \
# 8869        8869         395  Bluegrass Brewing Co. - East St. Matthew's
# 22125      22125        1199                    Founders Brewing Company
# 31822      31822        1199                    Founders Brewing Company
# 33500      33500        1199                    Founders Brewing Company
# 33678      33678        1199                    Founders Brewing Company
# ...          ...         ...                                         ...
# 1573069  1573069        1478                     Grand Ridge Brewing Co.
# 1573134  1573134        1478                     Grand Ridge Brewing Co.
# 1573157  1573157        1478                     Grand Ridge Brewing Co.
# 1580683  1580683         429                         Alaskan Brewing Co.
# 1580902  1580902         429                         Alaskan Brewing Co.
#
#          review_time  review_overall  review_aroma  review_appearance  \
# ...

# %%
df['review_profilename'].value_counts()
# Out:
# northyorksammy     5817
# BuckeyeNation      4661
# mikesgroove        4617
# Thorpe429          3518
# womencantsail      3497
#                    ...
# fnong2                1
# drewzline             1
# amandacrane           1
# mymasterpiece75       1
# joeebbs               1
# Name: review_profilename, Length: 33387, dtype: int64

# %%
df['review_profilename']=df['review_profilename'].replace(np.nan,'northyorksammy')

# %%
df[df['brewery_name'].isna()]
# Out:
#            index  brewery_id brewery_name  review_time  review_overall  \
# 651565    651565        1193          NaN   1301022066             2.0
# 659293    659293        1193          NaN   1290107698             4.0
# 659299    659299        1193          NaN   1289077001             3.5
# 659300    659300        1193          NaN   1289851033             3.5
# 659301    659301        1193          NaN   1289158632             3.5
# 659302    659302        1193          NaN   1289590065             3.5
# 659303    659303        1193          NaN   1298078926             3.0
# 659304    659304        1193          NaN   1292423271             4.5
# 659305    659305        1193          NaN   1289329962             3.5
# 1391043  1391043          27          NaN   1020244856             3.5
# 1391049  1391049          27          NaN   1143182956             2.5
# 1391050  1391050          27          NaN   1117963232             1.5
# ...

# %%
df['brewery_name'].value_counts()
# Out:
# Boston Beer Company (Samuel Adams)    39444
# Dogfish Head Brewery                  33839
# Stone Brewing Co.                     33066
# Sierra Nevada Brewing Co.             28751
# Bell's Brewery, Inc.                  25191
#                                       ...
# Brauerei Stolz GmbH & Co. KG              1
# Hausbrauerei Düll                         1
# Browar Grybów                             1
# Staro&#269;eský Pivovárek Dobruka        1
# Spire Brewery                             1
# Name: brewery_name, Length: 5742, dtype: int64

# %%
df['beer_style'].value_counts()
# Out:
# American IPA                        117586
# American Double / Imperial IPA       85977
# American Pale Ale (APA)              63469
# Russian Imperial Stout               54129
# American Double / Imperial Stout     50705
#                                      ...
# Gose                                   686
# Faro                                   609
# Roggenbier                             466
# Kvass                                  297
# Happoshu                               241
# Name: beer_style, Length: 104, dtype: int64

# %%
df['brewery_name']=df['brewery_name'].replace(np.nan,'Boston Beer Company (Samuel Adams)')

# %%
for i in df.columns:
    print(df[i].unique())
# Out:
# [      0       1       2 ... 1586611 1586612 1586613]
# [10325  1075   163 ... 12566  7337  6102]
# ['Vecchio Birraio' 'Caldera Brewing Company' 'Amstel Brouwerij B. V.' ...
#  'Wissey Valley Brewery' 'Outback Brewery Pty Ltd'
#  'Georg Meinel Bierbrauerei KG']
# [1234817823 1235915097 1235916604 ... 1160702513 1160023044 1160005319]
# [1.5 3.  4.  3.5 4.5 5.  2.  2.5 1.  0. ]
# [2.  2.5 3.  4.5 3.5 5.  4.  1.5 1. ]
# [2.5 3.  3.5 4.  5.  4.5 2.  1.  1.5 0. ]
# ['stcules' 'johnmichaelsen' 'oline73' ... 'hogshead' 'NyackNicky'
#  'joeebbs']
# ['Hefeweizen' 'English Strong Ale' 'Foreign / Export Stout'
#  'German Pilsener' 'American Double / Imperial IPA' 'Herbed / Spiced Beer'
#  'Light Lager' 'Oatmeal Stout' 'American Pale Lager' 'Rauchbier'
#  'American Pale Ale (APA)' 'American Porter' 'Belgian Strong Dark Ale'
#  'American IPA' 'American Stout' 'Russian Imperial Stout'
#  'American Amber / Red Ale' 'American Strong Ale' 'Märzen / Oktoberfest'
# ...

# %%
df.to_csv(r'C:\Users\James\Documents\CODE DATA ANALYSIS\module 2\beer_review.csv')

# %%
df['beer_name'].value_counts(ascending=False).head(10)
# Out:
# 90 Minute IPA                          3290
# India Pale Ale                         3130
# Old Rasputin Russian Imperial Stout    3111
# Sierra Nevada Celebration Ale          3000
# Two Hearted Ale                        2728
# Stone Ruination IPA                    2704
# Arrogant Bastard Ale                   2704
# Sierra Nevada Pale Ale                 2587
# Stone IPA (India Pale Ale)             2575
# Pliny The Elder                        2527
# Name: beer_name, dtype: int64

# %%
df.head()
# Out:
#    index  brewery_id             brewery_name  review_time  review_overall  \
# 0      0       10325          Vecchio Birraio   1234817823             1.5
# 1      1       10325          Vecchio Birraio   1235915097             3.0
# 2      2       10325          Vecchio Birraio   1235916604             3.0
# 3      3       10325          Vecchio Birraio   1234725145             3.0
# 4      4        1075  Caldera Brewing Company   1293735206             4.0
#
#    review_aroma  review_appearance review_profilename  \
# 0           2.0                2.5            stcules
# 1           2.5                3.0            stcules
# 2           2.5                3.0            stcules
# 3           3.0                3.5            stcules
# 4           4.5                4.0     johnmichaelsen
#
#                        beer_style  review_palate  review_taste  \
# 0                      Hefeweizen            1.5           1.5
# ...

# %%
df.shape
# Out:
# (1586614, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1586614 entries, 0 to 1586613
# Data columns (total 14 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   index               1586614 non-null  int64
#  1   brewery_id          1586614 non-null  int64
#  2   brewery_name        1586614 non-null  object
#  3   review_time         1586614 non-null  int64
#  4   review_overall      1586614 non-null  float64
#  5   review_aroma        1586614 non-null  float64
#  6   review_appearance   1586614 non-null  float64
#  7   review_profilename  1586614 non-null  object
#  8   beer_style          1586614 non-null  object
#  9   review_palate       1586614 non-null  float64
#  10  review_taste        1586614 non-null  float64
#  11  beer_name           1586614 non-null  object
#  12  beer_abv            1586614 non-null  float64
#  13  beer_beerid         1586614 non-null  int64
# dtypes: float64(6), int64(4), object(4)
# ...

# %%
df['brewery_name'].value_counts(10, ascending=True)
# Out:
# Het Brouw Café                        6.302730e-07
# Bonfire Brewing Co.                   6.302730e-07
# Brouwerij Montaigu                    6.302730e-07
# Erix Birra                            6.302730e-07
# Manchester Brewing Company            6.302730e-07
#                                           ...
# Bell's Brewery, Inc.                  1.587721e-02
# Sierra Nevada Brewing Co.             1.812098e-02
# Stone Brewing Co.                     2.084061e-02
# Dogfish Head Brewery                  2.132781e-02
# Boston Beer Company (Samuel Adams)    2.486994e-02
# Name: brewery_name, Length: 5742, dtype: float64

# %%
df['beer_name'].value_counts(10, ascending=True)
# Out:
# Sausa Weizen                           6.302730e-07
# Redhook Winter's Folly                 6.302730e-07
# Right Hook                             6.302730e-07
# Miloweizen                             6.302730e-07
# Lebewohl Pilsner                       6.302730e-07
#                                            ...
# Two Hearted Ale                        1.719385e-03
# Sierra Nevada Celebration Ale          1.890819e-03
# Old Rasputin Russian Imperial Stout    1.960779e-03
# India Pale Ale                         1.972755e-03
# 90 Minute IPA                          2.073598e-03
# Name: beer_name, Length: 56857, dtype: float64

# %%
df1 = df.pivot_table(index=["beer_name"],values=["review_time"]).sort_values(by='review_time',ascending=False).head(10)
df1
# Out:
#                                    review_time
# beer_name
# Belgo Sutra                       1.326252e+09
# Crank Yanker IPA                  1.326252e+09
# Icelandic White Beer              1.326239e+09
# Betty Brown Norwegian Brwon Ale   1.326237e+09
# Aass Gourmet Pale Ale             1.326236e+09
# White Dog Norwegian Wheat Beer    1.326236e+09
# La Stout - Vanille Et Café        1.326231e+09
# Saint-Jean-Baptiste (Annedd’ale)  1.326230e+09
# IPA Columbus                      1.326225e+09
# White Out                         1.326220e+09

# %%
df1.to_csv(r'C:\Users\James\Desktop\stream\df1.csv')

# %%
df2 = df.pivot_table(index=["beer_name"], values=["review_appearance","beer_style"]).sort_values(by="review_appearance", ascending=False).head(10)
df2
# Out:
#                                                   review_appearance
# beer_name
# Tall Tale Pale Ale (dry-hopped With Glacier)                    5.0
# Portsmouth Crazed Cossack Russian Imperial Stout                5.0
# Heaven And Hell Barleywine                                      5.0
# Haunted Series Russian Imperial Stout                           5.0
# Harvest Moon Amber                                              5.0
# Oliver Oatmeal Stout                                            5.0
# Pale Ale (Delta+Chinook)                                        5.0
# Cacique Amber Ale                                               5.0
# ADHD IPA                                                        5.0
# Hanska Baltic Porter                                            5.0

# %%
df2.to_csv(r'C:\Users\James\Desktop\stream\df2.csv')

# %%
df3 = df.pivot_table(index=["beer_name"], values=["review_aroma"]).sort_values(by="review_aroma", ascending=False).head(10)
df3
# Out:
#                                   review_aroma
# beer_name
# Southampton Belgian Red Ale                5.0
# Mittenwalder Werdenfelser Weisse           5.0
# Barrel Aged Stout                          5.0
# 1100.0                                     5.0
# Presciption Pils                           5.0
# Bray's Imperial Stout                      5.0
# Tantalizer Cask Ale                        5.0
# Engelbert Moonbeam                         5.0
# Founders Bourbon Maple Cerise              5.0
# Airbräu Krampus                            5.0

# %%
df3.to_csv(r'C:\Users\James\Desktop\stream\df3.csv')

# %%
df4 = df.pivot_table(index=["beer_name"], values=["review_taste"]).sort_values(by="review_taste", ascending=False).head(10)
df4.to_csv(r'C:\Users\James\Desktop\stream\df4.csv')

# %%
brewery=df.groupby("brewery_name").mean(10)
brewery.sort_values(by='review_time',ascending=False).head(10)
brewery.to_csv(r'C:\Users\James\Desktop\stream\brewery.csv')
brewery
# Out:
#                                 index  brewery_id   review_time  \
# brewery_name
# 't Hofbrouwerijke        6.670342e+05     13160.0  1.256720e+09
# (512) Brewing Company    1.413036e+06     17863.0  1.282753e+09
# 10 Barrel Brewing Co.    1.874940e+05     16873.0  1.293459e+09
# 1516 Brewing Company     8.345151e+05      4473.0  1.224275e+09
# 16 Mile Brewing Company  1.035061e+05     20688.0  1.294955e+09
# ...                               ...         ...           ...
# Ölvisholt Brugghús       6.647809e+05     17208.0  1.286116e+09
# Öufi Brauerei            1.045864e+06     18851.0  1.319317e+09
# Ølfabrikken              1.132015e+06     11063.0  1.229826e+09
# Ørbæk Bryggeri           1.576001e+06     15051.0  1.232312e+09
# Łódzkie Browary S.A.     8.347430e+05      5498.0  1.295147e+09
#
#                          review_overall  review_aroma  review_appearance  \
# brewery_name
# 't Hofbrouwerijke              3.702703      3.783784           3.851351
# ...

# %%
beername=df.sort_values(by='review_time',ascending=False).head(10)
beername.to_csv(r'C:\Users\James\Desktop\stream\beername.csv')

# %%
beername
# Out:
#            index  brewery_id                                brewery_name  \
# 551371    551371       22194                           Flat Tail Brewing
# 551392    551392       22194                           Flat Tail Brewing
# 400524    400524         694                      Tröegs Brewing Company
# 1153730  1153730         454                     Arcadia Brewing Company
# 562035    562035         423                       Boulevard Brewing Co.
# 1134366  1134366         863               Russian River Brewing Company
# 428421    428421        5142                          Oettinger Brauerei
# 989617    989617         859  Snoqualmie Falls Brewing Company & Taproom
# 1420840  1420840         738                           Brasserie Fantôme
# 852288    852288         417               August Schell Brewing Company
#
#          review_time  review_overall  review_aroma  review_appearance  \
# 551371    1326285348             4.0           4.0                4.0
# ...

# %%
import altair as alt



alt.Chart(beername).mark_area().encode(
    alt.X('beer_abv',
        axis=alt.Axis(format='%Y', domain=False, tickSize=0)
    ),
    alt.Y('beer_name', stack='center', axis=None),
    alt.Color('beer_name',
        scale=alt.Scale(scheme='category20b')
    )
).interactive()
# Out:
# alt.Chart(...)

# %%
import seaborn as sns
sns.regplot(x="review_time", y='review_taste', data=beername)
# Out:
# <AxesSubplot:xlabel='review_time', ylabel='review_taste'>

# %%
sns.regplot(x="review_aroma", y='review_taste', data=brewery)

hexbin_fig = plt.figure(figsize=(8,7))

hexbin_ax = hexbin_fig.add_subplot(111)

brewery.plot.hexbin(x="review_appearance", y="review_taste",
                             reduce_C_function=np.mean,
                             gridsize=25,
                             #cmap="Greens",
                             ax=hexbin_ax,
                             title="Concentration of Measurements"
                            );

# %%
sns.distplot(brewery["review_overall"])
# Out:
# C:\Users\James\AppData\Local\Temp\ipykernel_2568\413783263.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(brewery["review_overall"])
# <AxesSubplot:xlabel='review_overall', ylabel='Density'>
